# %% [markdown]
# <a href="https://colab.research.google.com/github/YRajiv/-COMPETATIVE-_PROGRAMMING_1357/blob/main/week_4_7mon(FENWICK_TREES).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#problem 1:
class FenwickTree:
    def __init__(self, n):
        self.n = n
        self.tree = [0] * (n + 1)

    def update(self, i, delta):
        while i <= self.n:
            self.tree[i] += delta
            i += i & -i

    def query(self, i):
        total = 0
        while i > 0:
            total += self.tree[i]
            i -= i & -i
        return total

print("\n--- Student Attendance Analysis ---")

# INPUT SECTION
n = int(input("Enter total number of days: "))

arr = list(map(int, input(
    "Enter attendance points for each day (space-separated): ").split()))

ft = FenwickTree(n)

# Build tree
for i in range(n):
    ft.update(i + 1, arr[i])

# Query
day_query = int(input(
    "Enter the day number to calculate total attendance up to that day: "))

print("Total attendance till Day", day_query, "=", ft.query(day_query))

# Update
day_update = int(input(
    "Enter the day number where attendance needs correction: "))

new_value = int(input(
    "Enter the NEW attendance value for that day: "))

delta = new_value - arr[day_update - 1]
arr[day_update - 1] = new_value
ft.update(day_update, delta)

# Query again
day_query = int(input(
    "Enter the day number to calculate attendance after update: "))

print("Updated total attendance till Day", day_query, "=", ft.query(day_query))
# Out:
# --- Student Attendance Analysis ---
# Enter total number of days: 5
# Enter attendance points for each day (space-separated): 1 2 1 2 1
# Enter the day number to calculate total attendance up to that day: 4
# Total attendance till Day 4 = 6
# Enter the day number where attendance needs correction: 3
# Enter the NEW attendance value for that day: 2
# Enter the day number to calculate attendance after update: 4
# Updated total attendance till Day 4 = 7

# %%
#problem 2
class FenwickTree:
    def __init__(self, n):
        self.n = n
        self.tree = [0] * (n + 1)

    def update(self, i, delta):
        while i <= self.n:
            self.tree[i] += delta
            i += i & -i

    def query(self, i):
        total = 0
        while i > 0:
            total += self.tree[i]
            i -= i & -i
        return total


print("\n--- Daily Sales Revenue Analysis ---")

# -------- INPUT SECTION --------
n = int(input("Enter total number of days: "))

arr = list(map(int, input(
    "Enter daily sales revenue for each day (space-separated): "
).split()))

ft = FenwickTree(n)

# Build Fenwick Tree
for i in range(n):
    ft.update(i + 1, arr[i])

# -------- QUERY --------
day_query = int(input(
    "Enter the day number to calculate total revenue up to that day: "))

print("Total sales revenue till Day", day_query, "=", ft.query(day_query))

# -------- UPDATE --------
day_update = int(input(
    "Enter the day number where revenue needs correction: "))

new_value = int(input(
    "Enter the NEW revenue value for that day: "))

delta = new_value - arr[day_update - 1]
arr[day_update - 1] = new_value
ft.update(day_update, delta)

# -------- QUERY AFTER UPDATE --------
day_query = int(input(
    "Enter the day number to calculate revenue after update: "))

print("Updated total sales revenue till Day", day_query, "=", ft.query(day_query))
# Out:
# --- Daily Sales Revenue Analysis ---
# Enter total number of days: 7
# Enter daily sales revenue for each day (space-separated): 100 101 102 103 104 105 106 107
# Enter the day number to calculate total revenue up to that day: 6
# Total sales revenue till Day 6 = 615
# Enter the day number where revenue needs correction: 5
# Enter the NEW revenue value for that day: 160
# Enter the day number to calculate revenue after update: 6
# Updated total sales revenue till Day 6 = 671
